# %%
import requests
import datetime
from newsapi.newsapi_client import NewsApiClient
from transformers import pipeline

# %%
from bs4 import BeautifulSoup

# %%
newskey = '067520582efd4bd1992d2716b35afdc5'

# %%
domains = "fxstreet.com,marketpulse.com,rnsdaily.com,marketwatch.com,investorplace.com,seekingalpha.com,dailyfx.com,cnbc.com,investors.com,nasdaq.com,barrons.com,zacks.com,finance.yahoo.com,reuters.com,bloomberg.com,businessinsider.com,wsj.com,ft.com,cnn.com,economist.com,thestreet.com"

# %%
q = 'PLUG plug power'
dstart = '2021-11-01'
dend = '2021-11-16'

# %%
def query_newsapi(query, d_start, d_end, pages=1, pageSize=200):
    url = ('https://newsapi.org/v2/everything?'
      'q='+query
      '&domains='+domains
      '&from='+d_start
      '&to='+d_end
      '&language=en'
      '&sortBy=publishedAt'
      '&apikey='+newskey)
    
    response = requests.get(url)

# %%
url = ('https://newsapi.org/v2/everything?'
      'q='+q+'&'
      'domains='+domains+'&'
      'from='+dstart+'&'
      'to='+dend+'&'
      'language=en&'
      'sortBy=publishedAt&'
      'apikey='+newskey
      )

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response = response.json()

# %%
for k,v in response.items():
    print(k)
# Out:
# status
# totalResults
# articles

# %%
for x in response['articles'][0]:
    print(x)
# Out:
# source
# author
# title
# description
# url
# urlToImage
# publishedAt
# content

# %%
print(response['articles'][0]['publishedAt'])
# Out:
# 2021-11-13T17:53:04Z

# %%
print(response['totalResults'])
# Out:
# 71

# %%
print(len(response['articles']))
# Out:
# 20

# %%
c=0
j=0
for k in response['articles']:
    j = j+1
    headers = {"User-Agent":"Mozilla/5.0"}
    turl = requests.get(k['url'], headers = headers)
    if str(turl.status_code) != "200":
        c = c +1
        print(k['url'])
        soup = BeautifulSoup(turl.content,'html.parser')

print(c)
print(j)
# Out:
# https://seekingalpha.com/news/3753450-fuel-cell-stocks-power-to-top-industrial-gainers-while-space-stocks-land-among-losers
# https://seekingalpha.com/article/4460121-gold-stocks-bouncing-hard
# https://seekingalpha.com/article/4460085-plug-power-scrutinizing-most-recent-guidance-raise
# https://seekingalpha.com/article/4460069-shareholder-yield-3-high-quality-dividend-stocks
# https://www.thestreet.com/investing/coker-palmer-lack-of-detail-plug-power
# https://seekingalpha.com/article/4459999-alcoa-corporation-aa-ceo-roy-harvey-on-q3-2021-results-earnings-call-transcript
# https://seekingalpha.com/article/4459956-occam-razor-tesla-tsla-bulls-ignore-breaks-long-term-expectations
# https://seekingalpha.com/news/3752768-nikola-jumps-after-inking-lease-deal-for-100-fcev-trucks
# 8
# 20

# %%
print(response['articles'][14]['url'])
# Out:
# https://www.thestreet.com/investing/coker-palmer-lack-of-detail-plug-power

# %%
test = 'In an apparent case of buy the rumor, sell the news, shares of Plug Power Inc. PLUG, -1.79% pulled back 4.4% in morning trading, putting them on track to snap a seven-day win streak, after the after the hydrogen and fuel-cell systems company unveiled some highlights of its much-anticipated annual Symposium. The stock had soared 12.8% on Wednesday, after a Morgan Stanley upgrade, and had soared 38% over the past seven days. The company said it now expects 2022 sales of $825 million to $850 million, which is above the FactSet consensus of $759.7 million. Plug also established 2025 sales guidance of $3 billion, which compares with the current FactSet consensus of $2.22 billion. Among other highlights, Plug said it was partnering with Fortescue Future Industries to form a 50-50 joint venture to build a gigafactory in Australia, entered into an agreement to buy liquified hydrogen transportation company Cryo Technologies and confirmed plans to generate 500 tons per day of liquid green hydrogen by the end of 2025. The stock has run up 21.0% over the past three months, while the S&P 500 SPX, +0.75% has gained 1.1%.'

# %%
classifier = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Some layers from the model checkpoint at distilbert-base-uncased-finetuned-sst-2-english were not used when initializing TFDistilBertForSequenceClassification: ['dropout_19']
# - This IS expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
classifier(test)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9145223498344421}]

# %%
uurl = response['articles'][14]['url']
print(uurl)
# Out:
# https://www.thestreet.com/investing/coker-palmer-lack-of-detail-plug-power

# %%
uspon = requests.get(uurl)

# %%
print(uspon.content)
# Out:
# b'<!DOCTYPE html><html id="phx-wrapper" lang="en-us"><head><title>Plug Power\'s Lowered Guidance Lacking Detail, Analyst Says - TheStreet</title><link rel="canonical" href="https://www.thestreet.com/investing/coker-palmer-lack-of-detail-plug-power"><meta property="author" content="Dan Weil"><meta name="description" content="\'Details were not provided,\' Coker Palmer analyst Vaibhav Vaishnav writes. He has a price target of $13 for the stock, compared to its recent quote of $32.08."><meta name="keywords" content="Earnings Preview,Technology,Earnings,Earnings Forecast,Renewable energy,Renewable Energy,INVESTING,FuelCell Energy,Earnings,STOCKS"><meta name="section" content="INVESTING"><meta name="pagetype" content="article"><meta name="tickers" content="PLUG"><meta name="companies" content="Plug Power Inc."><meta name="tags" content="Earnings Preview, Earnings, Renewable energy"><meta name="robots" content="max-image-preview:large"><meta name="item-id" content="ci028fc39ee00025e7"><met
# ...

# %%
print(uspon.status_code)
# Out:
# 200

# %%
def extract_source(url):
    headers = {"User-Agent":"Mozilla/5.0"}
    s = requests.get(url, headers=headers).text
    return s

# %%
soup = BeautifulSoup(uspon.content, 'html.parser')

# %%
from requests_html import AsyncHTMLSession

# %%
session = AsyncHTMLSession()

# %%
r = session.get(uurl)

# %%
r = r.result()

# %%
print(r.html.text)
# Out:
# Plug Power Stock: Scrutinizing Most Recent Guidance Raise (NASDAQ:PLUG) | Seeking Alpha
# ...

# %%
soup = BeautifulSoup(r.html.text,'html.parser')
print(soup.prettify())
# Out:
# Plug Power Stock: Scrutinizing Most Recent Guidance Raise (NASDAQ:PLUG) | Seeking Alpha
# ...

# %%
print(soup.get_text())
# Out:
# Plug Power's Lowered Guidance Lacking Detail, Analyst Says - TheStreet
# October 18, 2021Log InReceive full access to our market insights, commentary, newsletters, breaking news alerts, and more.Forgot your password?Log InDon't have an account? Sign Up HereJoin UsReceive full access to our market insights, commentary, newsletters, breaking news alerts, and more.I agree to TheMaven'sTerms andPolicySign UpAlready have an account? Login here
#
#
# INVESTINGBITCOINCANNABISCRYPTOCURRENCYETFSEARNINGSFIXED INCOMEFUNDSFUTURESOPTIONSRATINGSREITSSTOCKSSearch
#
#
# ...

# %%
s = str(soup.get_text())
print(s)
# Out:
# Plug Power's Lowered Guidance Lacking Detail, Analyst Says - TheStreet
# October 18, 2021Log InReceive full access to our market insights, commentary, newsletters, breaking news alerts, and more.Forgot your password?Log InDon't have an account? Sign Up HereJoin UsReceive full access to our market insights, commentary, newsletters, breaking news alerts, and more.I agree to TheMaven'sTerms andPolicySign UpAlready have an account? Login here
#
#
# INVESTINGBITCOINCANNABISCRYPTOCURRENCYETFSEARNINGSFIXED INCOMEFUNDSFUTURESOPTIONSRATINGSREITSSTOCKSSearch
#
#
# ...

# %%
url = 'https://seekingalpha.com/symbol/'+ symbol + '/more_focus?page=' + str(i)
hdr = {'User-Agent': 'Mozilla/5.0'}
req = urllib2.Request(url, headers=hdr)
html = urllib2.urlopen(req).read()
soup = BeautifulSoup(html)
contents = soup.find_all("div", class_='\\"symbol_article\\"')
